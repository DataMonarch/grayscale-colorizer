# %%
import imp
import os
import cv2
import pdb
import glob
import pandas as pd
import numpy as np
from tqdm import tqdm
from multiprocessing import Pool
import torch
from torch import optim
from torch import Tensor
import torch.nn as nn
import torch.nn.functional as F
# from torch.nn.functional import InterpolationMode
import torchvision.models as models
from torchvision import transforms, utils
from torch.utils.data import Dataset, DataLoader
import logging
import datetime
import sys
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/home/toghrul/Pictures/gray.jpeg")
plt.imshow(img)

# %%
red = np.zeros((1, 1, 3), np.uint8)
red[:] = (0,0,255)

green = np.zeros((1, 1, 3), np.uint8)
green[:] = (0,255,0)

# create 1 pixel blue image
blue = np.zeros((1, 1, 3), np.uint8)
blue[:] = (255,0,0)

lut = np.concatenate((blue, red, green), axis=0)

# resize lut to 256 values
lut = cv2.resize(lut, (1,256), interpolation=cv2.INTER_CUBIC)

result = cv2.LUT(img, lut)
plt.imshow(result)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
img[:, :, 1:] = 0

# %%
plt.imshow(img)
